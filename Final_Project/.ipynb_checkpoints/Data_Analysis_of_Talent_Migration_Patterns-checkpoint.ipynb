# %% [markdown]
# # Data Analysis of Talent Migration Patterns

# %% [markdown]
#   Included dataset shows the movement of LinkedIn members across the world between 2015 and 2019.
#
#
#  *Data source - World Bank https://datacatalog.worldbank.org/dataset/talent-migration-linkedin-data*
#
# The **Net Migration** here refers to the net gain or loss of members from another country divided by the average LinkedIn membership of the target (or selected) country during the time period, multiplied by 10,000.

# %% [markdown]
# #### The analysis includes the following sections:
#   1. Data Understanding & Preparation
#   2. Data Visualisation
#   3. Creating Geographical Map
#   4. Extracting Insights from Armenian Talent Migration
#   5. Exploring Flow Directions (based on income groups)

# %%
import sys
sys.path.append('/usr/local/lib/python3.9/site-packages')

# %% [markdown]
# ## 1. Data Understanding & Preparation

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import geopandas as gpd
import json
from bokeh.io import output_notebook, show, output_file
from bokeh.plotting import figure
from bokeh.models import GeoJSONDataSource, LinearColorMapper, ColorBar
from bokeh.palettes import brewer

# %%
data = pd.read_csv("country_migration_public.csv")

# %%
data.head()
# Out:
#   base_country_code     base_country_name   base_lat  base_long  \
# 0                ae  United Arab Emirates  23.424076  53.847818
# 1                ae  United Arab Emirates  23.424076  53.847818
# 2                ae  United Arab Emirates  23.424076  53.847818
# 3                ae  United Arab Emirates  23.424076  53.847818
# 4                ae  United Arab Emirates  23.424076  53.847818
#
#   base_country_wb_income      base_country_wb_region target_country_code  \
# 0            High Income  Middle East & North Africa                  af
# 1            High Income  Middle East & North Africa                  dz
# 2            High Income  Middle East & North Africa                  ao
# 3            High Income  Middle East & North Africa                  ar
# 4            High Income  Middle East & North Africa                  am
#
#   target_country_name  target_lat  target_long  ... net_per_10K_2019  \
# 0         Afghanistan   33.939110    67.709953  ...            -0.02
# 1             Algeria   28.033886     1.659626  ...             0.78
# 2              Angola  -11.202692    17.873887  ...            -0.06
# 3           Argentina  -38.416097   -63.616672  ...             0.23
# 4             Armenia   40.069099    45.038189  ...             0.02
#
#   Unnamed: 17  Unnamed: 18  Unnamed: 19  Unnamed: 20  Unnamed: 21  \
# 0         NaN          NaN          NaN          NaN          NaN
# 1         NaN          NaN          NaN          NaN          NaN
# 2         NaN          NaN          NaN          NaN          NaN
# 3         NaN          NaN          NaN          NaN          NaN
# 4         NaN          NaN          NaN          NaN          NaN
#
#    Unnamed: 22  Unnamed: 23  Unnamed: 24  Unnamed: 25
# 0          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN
#
# [5 rows x 26 columns]

# %%
data.tail()
# Out:
#      base_country_code base_country_name   base_lat  base_long  \
# 4143                zw          Zimbabwe -19.015438  29.154857
# 4144                zw          Zimbabwe -19.015438  29.154857
# 4145                zw          Zimbabwe -19.015438  29.154857
# 4146                zw          Zimbabwe -19.015438  29.154857
# 4147                zw          Zimbabwe -19.015438  29.154857
#
#      base_country_wb_income base_country_wb_region target_country_code  \
# 4143             Low Income     Sub-Saharan Africa                  za
# 4144             Low Income     Sub-Saharan Africa                  ae
# 4145             Low Income     Sub-Saharan Africa                  gb
# 4146             Low Income     Sub-Saharan Africa                  us
# 4147             Low Income     Sub-Saharan Africa                  zm
#
#        target_country_name  target_lat  target_long  ... net_per_10K_2019  \
# 4143          South Africa  -30.559482    22.937506  ...           -20.76
# 4144  United Arab Emirates   23.424076    53.847818  ...            -3.19
# 4145        United Kingdom   55.378051    -3.435973  ...            -1.97
# 4146         United States   37.090240   -95.712891  ...             5.25
# 4147                Zambia  -13.133897    27.849332  ...             0.33
#
#      Unnamed: 17  Unnamed: 18  Unnamed: 19  Unnamed: 20  Unnamed: 21  \
# 4143         NaN          NaN          NaN          NaN          NaN
# 4144         NaN          NaN          NaN          NaN          NaN
# 4145         NaN          NaN          NaN          NaN          NaN
# 4146         NaN          NaN          NaN          NaN          NaN
# 4147         NaN          NaN          NaN          NaN          NaN
#
#       Unnamed: 22  Unnamed: 23  Unnamed: 24  Unnamed: 25
# 4143          NaN          NaN          NaN          NaN
# 4144          NaN          NaN          NaN          NaN
# 4145          NaN          NaN          NaN          NaN
# 4146          NaN          NaN          NaN          NaN
# 4147          NaN          NaN          NaN          NaN
#
# [5 rows x 26 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4148 entries, 0 to 4147
# Data columns (total 26 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   base_country_code         4148 non-null   object
#  1   base_country_name         4148 non-null   object
#  2   base_lat                  4148 non-null   float64
#  3   base_long                 4148 non-null   float64
#  4   base_country_wb_income    4148 non-null   object
#  5   base_country_wb_region    4148 non-null   object
#  6   target_country_code       4148 non-null   object
#  7   target_country_name       4148 non-null   object
#  8   target_lat                4148 non-null   float64
#  9   target_long               4148 non-null   float64
#  10  target_country_wb_income  4148 non-null   object
#  11  target_country_wb_region  4148 non-null   object
#  12  net_per_10K_2015          4148 non-null   float64
#  13  net_per_10K_2016          4148 non-null   float64
#  14  net_per_10K_2017          4148 non-null   float64
#  15  net_per_10K_2018          4148 non-null   float64
#  16  net_per_10K_2019          4148 non-null   float64
#  17  Unnamed: 17               0 non-null      float64
#  18  Unnamed: 18               0 non-null      float64
#  19  Unnamed: 19               0 non-null      float64
#  20  Unnamed: 20               0 non-null      float64
#  21  Unnamed: 21               0 non-null      float64
#  22  Unnamed: 22               0 non-null      float64
#  23  Unnamed: 23               0 non-null      float64
#  24  Unnamed: 24               0 non-null      float64
#  25  Unnamed: 25               0 non-null      float64
# dtypes: float64(18), object(8)
# memory usage: 842.7+ KB

# %%
data.columns
# Out:
# Index(['base_country_code', 'base_country_name', 'base_lat', 'base_long',
#        'base_country_wb_income', 'base_country_wb_region',
#        'target_country_code', 'target_country_name', 'target_lat',
#        'target_long', 'target_country_wb_income', 'target_country_wb_region',
#        'net_per_10K_2015', 'net_per_10K_2016', 'net_per_10K_2017',
#        'net_per_10K_2018', 'net_per_10K_2019', 'Unnamed: 17', 'Unnamed: 18',
#        'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22',
#        'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25'],
#       dtype='object')

# %% [markdown]
# ### Renaming some columns

# %%
cols= ['net_per_10K_2015','net_per_10K_2016', 'net_per_10K_2017','net_per_10K_2018', 'net_per_10K_2019']

# %%
cols_ = {}
for i in cols:
    cols_[i] = i.split('_')[-1]

# %%
data.rename(columns=cols_, inplace=True)

# %% [markdown]
# ### Getting rid of empty columns

# %%
cols_to_drop = ['base_lat', 'base_long','target_lat',
       'target_long','Unnamed: 17', 'Unnamed: 18',
       'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22',
       'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25']
for col in cols_to_drop:
    data.drop(col, axis=1, inplace=True)

# %%
countries = data['base_country_name'].unique()

# %%
f"The dataset includes {len(countries)-1} countries."
# Out:
# 'The dataset includes 139 countries.'

# %%
data
# Out:
#      base_country_code     base_country_name base_country_wb_income  \
# 0                   ae  United Arab Emirates            High Income
# 1                   ae  United Arab Emirates            High Income
# 2                   ae  United Arab Emirates            High Income
# 3                   ae  United Arab Emirates            High Income
# 4                   ae  United Arab Emirates            High Income
# ...                ...                   ...                    ...
# 4143                zw              Zimbabwe             Low Income
# 4144                zw              Zimbabwe             Low Income
# 4145                zw              Zimbabwe             Low Income
# 4146                zw              Zimbabwe             Low Income
# 4147                zw              Zimbabwe             Low Income
#
#           base_country_wb_region target_country_code   target_country_name  \
# 0     Middle East & North Africa                  af           Afghanistan
# 1     Middle East & North Africa                  dz               Algeria
# 2     Middle East & North Africa                  ao                Angola
# 3     Middle East & North Africa                  ar             Argentina
# 4     Middle East & North Africa                  am               Armenia
# ...                          ...                 ...                   ...
# 4143          Sub-Saharan Africa                  za          South Africa
# 4144          Sub-Saharan Africa                  ae  United Arab Emirates
# 4145          Sub-Saharan Africa                  gb        United Kingdom
# 4146          Sub-Saharan Africa                  us         United States
# 4147          Sub-Saharan Africa                  zm                Zambia
#
#      target_country_wb_income    target_country_wb_region   2015   2016  \
# 0                  Low Income                  South Asia   0.19   0.16
# 1         Upper Middle Income  Middle East & North Africa   0.19   0.25
# 2         Lower Middle Income          Sub-Saharan Africa  -0.01   0.04
# 3                 High Income   Latin America & Caribbean   0.16   0.18
# 4         Upper Middle Income       Europe & Central Asia   0.10   0.05
# ...                       ...                         ...    ...    ...
# 4143      Upper Middle Income          Sub-Saharan Africa  -2.98 -11.79
# 4144              High Income  Middle East & North Africa  -2.50  -2.49
# 4145              High Income       Europe & Central Asia   3.91   4.66
# 4146              High Income               North America  38.60  37.76
# 4147      Lower Middle Income          Sub-Saharan Africa   0.70   2.47
#
#        2017   2018   2019
# 0      0.11  -0.05  -0.02
# 1      0.57   0.55   0.78
# 2      0.11  -0.02  -0.06
# 3      0.04   0.01   0.23
# 4      0.03  -0.01   0.02
# ...     ...    ...    ...
# 4143  -9.10 -12.08 -20.76
# 4144  -2.21  -1.68  -3.19
# 4145   0.74  -0.66  -1.97
# 4146  10.09   6.06   5.25
# 4147   0.83   1.21   0.33
#
# [4148 rows x 13 columns]

# %%
data.describe()
# Out:
#               2015         2016         2017         2018         2019
# count  4148.000000  4148.000000  4148.000000  4148.000000  4148.000000
# mean      0.461757     0.150248    -0.080272    -0.040591    -0.022743
# std       5.006530     4.201118     3.203092     3.593876     3.633247
# min     -37.010000   -40.890000   -43.660000   -56.220000   -50.330000
# 25%      -0.150000    -0.190000    -0.210000    -0.210000    -0.210000
# 50%       0.000000     0.000000     0.000000     0.000000     0.000000
# 75%       0.240000     0.220000     0.160000     0.170000     0.180000
# max     150.680000   124.480000    87.000000    91.410000    87.710000

# %%
data.loc[data['2015'] == 150.680000]
# Out:
#      base_country_code base_country_name base_country_wb_income  \
# 2487                lu        Luxembourg            High Income
#
#      base_country_wb_region target_country_code target_country_name  \
# 2487  Europe & Central Asia                  fr              France
#
#      target_country_wb_income target_country_wb_region    2015    2016  2017  \
# 2487              High Income    Europe & Central Asia  150.68  124.48  87.0
#
#        2018   2019
# 2487  91.41  87.71

# %% [markdown]
# The biggest inflow (2015-2019) was in Luxembourd from France in 2015.

# %%
data.loc[data['2018'] == -56.220000]
# Out:
#      base_country_code base_country_name base_country_wb_income  \
# 3658                tn           Tunisia    Lower Middle Income
#
#           base_country_wb_region target_country_code target_country_name  \
# 3658  Middle East & North Africa                  fr              France
#
#      target_country_wb_income target_country_wb_region   2015   2016   2017  \
# 3658              High Income    Europe & Central Asia -18.98 -31.33 -43.66
#
#        2018   2019
# 3658 -56.22 -50.33

# %% [markdown]
# The biggest ouflow (2015-2019) was from Tunisia to France in 2018.

# %%
data.dtypes
# Out:
# base_country_code            object
# base_country_name            object
# base_country_wb_income       object
# base_country_wb_region       object
# target_country_code          object
# target_country_name          object
# target_country_wb_income     object
# target_country_wb_region     object
# 2015                        float64
# 2016                        float64
# 2017                        float64
# 2018                        float64
# 2019                        float64
# dtype: object

# %%
data.isna().sum()
# Out:
# base_country_code           0
# base_country_name           0
# base_country_wb_income      0
# base_country_wb_region      0
# target_country_code         0
# target_country_name         0
# target_country_wb_income    0
# target_country_wb_region    0
# 2015                        0
# 2016                        0
# 2017                        0
# 2018                        0
# 2019                        0
# dtype: int64

# %%
data.columns
# Out:
# Index(['base_country_code', 'base_country_name', 'base_country_wb_income',
#        'base_country_wb_region', 'target_country_code', 'target_country_name',
#        'target_country_wb_income', 'target_country_wb_region', '2015', '2016',
#        '2017', '2018', '2019'],
#       dtype='object')

# %% [markdown]
# ### Grouping and creating new dataframes for each country and region

# %%
dt = data.groupby('base_country_name').sum().reset_index()

# %%
dt
# Out:
#       base_country_name   2015   2016   2017   2018   2019
# 0           Afghanistan   6.54   5.24 -34.27  15.85  23.01
# 1               Albania   4.78   0.59 -18.80  -5.05 -16.58
# 2               Algeria  -5.31 -12.26 -34.10 -23.00 -23.47
# 3                Angola  73.98  13.90  -9.24   4.62  19.07
# 4             Argentina  -0.20   2.14   8.19  14.72  -8.77
# ..                  ...    ...    ...    ...    ...    ...
# 135             Vietnam   4.75  -6.52 -15.12  -9.08  -7.94
# 136  West Bank and Gaza   6.75  -5.46 -11.79 -14.13 -15.59
# 137         Yemen, Rep. -10.27 -11.99  -7.16  -4.38   2.89
# 138              Zambia  93.77  64.92  20.12  23.66  27.05
# 139            Zimbabwe  45.83  38.31   0.97  -9.03 -23.98
#
# [140 rows x 6 columns]

# %%
region_dt = data.groupby('base_country_wb_region').sum().reset_index()

# %%
region_dt
# Out:
#        base_country_wb_region    2015    2016    2017    2018    2019
# 0         East Asia & Pacific  341.14  189.28   94.83  133.17  132.22
# 1       Europe & Central Asia  160.59   64.38   73.43  226.29  354.42
# 2   Latin America & Caribbean  122.95 -109.09 -250.61 -371.23 -375.41
# 3  Middle East & North Africa  437.01   69.57 -108.09   -9.48  -59.21
# 4               North America   11.86   26.79   37.98   50.69   60.29
# 5                  South Asia  -66.53  -99.02 -139.47 -101.33 -103.43
# 6          Sub-Saharan Africa  908.35  481.32  -41.04  -96.48 -103.22

# %%
regions_transposed = region_dt.set_index('base_country_wb_region').transpose()

# %%
regions_transposed
# Out:
# base_country_wb_region  East Asia & Pacific  Europe & Central Asia  \
# 2015                                 341.14                 160.59
# 2016                                 189.28                  64.38
# 2017                                  94.83                  73.43
# 2018                                 133.17                 226.29
# 2019                                 132.22                 354.42
#
# base_country_wb_region  Latin America & Caribbean  Middle East & North Africa  \
# 2015                                       122.95                      437.01
# 2016                                      -109.09                       69.57
# 2017                                      -250.61                     -108.09
# 2018                                      -371.23                       -9.48
# 2019                                      -375.41                      -59.21
#
# base_country_wb_region  North America  South Asia  Sub-Saharan Africa
# 2015                            11.86      -66.53              908.35
# 2016                            26.79      -99.02              481.32
# 2017                            37.98     -139.47              -41.04
# 2018                            50.69     -101.33              -96.48
# 2019                            60.29     -103.43             -103.22

# %% [markdown]
# -----------------------------------

# %% [markdown]
# ## 2. Data Visualisation

# %%
cls = ['cyan', 'silver','yellowgreen','lightpink', 'gold', 'darkslategrey','deeppink','palevioletred']
regions_transposed.plot.line(figsize=(12,9), color =cls, lw = 3)

plt.xticks(rotation=45)
plt.title('Net Migration Trends, 2016-2019', fontsize=15)
plt.show()

# %% [markdown]
# #### Correlation

# %%
dt.corr()
# Out:
#           2015      2016      2017      2018      2019
# 2015  1.000000  0.939707  0.783504  0.722801  0.727656
# 2016  0.939707  1.000000  0.902038  0.837156  0.816151
# 2017  0.783504  0.902038  1.000000  0.951845  0.900251
# 2018  0.722801  0.837156  0.951845  1.000000  0.957311
# 2019  0.727656  0.816151  0.900251  0.957311  1.000000

# %%
plt.figure(figsize=(15,9))
l = ['yellowgreen','gold','cyan', 'silver','lightpink','palevioletred','purple','deeppink']
sns.heatmap(dt.corr(),cmap=l,annot=True,linewidths=3)
plt.title('Correlation between migration rates of different years', fontsize=15)
plt.show()

# %%
plt.figure(figsize=(10,6))
dt.boxplot(color = 'cyan')
plt.show()

# %%
dt.hist(color="deeppink", alpha=0.7, figsize=(15,9), bins=50, grid=False)
plt.show()

# %% [markdown]
# The last two graphs helped to implement an approximate classification to customise the geographic map in the next section.

# %% [markdown]
# -------------

# %% [markdown]
# ## 3. Creating Geographical Map

# %%
shapefile = 'ne_110m_admin_0_countries/ne_110m_admin_0_countries.shp'

# %%
gdf = gpd.read_file(shapefile)[['ADMIN', 'ADM0_A3', 'geometry']]

# %%
gdf.columns = ['country', 'country_code', 'geometry']
gdf.head()
# Out:
#                        country country_code  \
# 0                         Fiji          FJI
# 1  United Republic of Tanzania          TZA
# 2               Western Sahara          SAH
# 3                       Canada          CAN
# 4     United States of America          USA
#
#                                             geometry
# 0  MULTIPOLYGON (((180.00000 -16.06713, 180.00000...
# 1  POLYGON ((33.90371 -0.95000, 34.07262 -1.05982...
# 2  POLYGON ((-8.66559 27.65643, -8.66512 27.58948...
# 3  MULTIPOLYGON (((-122.84000 49.00000, -122.9742...
# 4  MULTIPOLYGON (((-122.84000 49.00000, -120.0000...

# %%
gdf.country
# Out:
# 0                             Fiji
# 1      United Republic of Tanzania
# 2                   Western Sahara
# 3                           Canada
# 4         United States of America
#                   ...
# 172             Republic of Serbia
# 173                     Montenegro
# 174                         Kosovo
# 175            Trinidad and Tobago
# 176                    South Sudan
# Name: country, Length: 177, dtype: object

# %%
print(gdf[gdf['country'] == 'Antarctica'])
gdf = gdf.drop(gdf.index[159])
# Out:
#         country country_code  \
# 159  Antarctica          ATA
#
#                                               geometry
# 159  MULTIPOLYGON (((-48.66062 -78.04702, -48.15140...

# %%
map_dt = data.groupby('base_country_name').sum().reset_index()

# %%
map_dt.head()
# Out:
#   base_country_name   2015   2016   2017   2018   2019
# 0       Afghanistan   6.54   5.24 -34.27  15.85  23.01
# 1           Albania   4.78   0.59 -18.80  -5.05 -16.58
# 2           Algeria  -5.31 -12.26 -34.10 -23.00 -23.47
# 3            Angola  73.98  13.90  -9.24   4.62  19.07
# 4         Argentina  -0.20   2.14   8.19  14.72  -8.77

# %% [markdown]
# ### Corresponding country names from two datasets

# %%
a = list(map_dt['base_country_name'])

# %%
b = list(gdf['country'])

# %%
not_same_countries = []
for i in b:
    if i not in a:
        not_same_countries.append(i)

# %%
not_same_countries.sort()

# %%
not_same_countries2 = []
for i in a:
    if i not in b:
        not_same_countries2.append(i)

# %%
map_dt['base_country_name'] = map_dt['base_country_name'].replace(['Bahamas, The','Congo, Dem. Rep.','Czech Republic','Egypt, Arab Rep.','Iran, Islamic Rep.','Korea, Rep.','Macedonia, FYR','Slovak Republic','Syrian Arab Republic','Tanzania','United States','Venezuela, RB','Yemen, Rep.'],['The Bahamas','Democratic Republic of the Congo','Czechia','Egypt','Iran','South Korea','Macedonia','Slovakia','Syria','United Republic of Tanzania','United States of America','Venezuela','Yemen'])

# %%
map_dt_2019 = map_dt.loc[:, ['base_country_name', '2019']]

# %%
map_dt_2019
# Out:
#       base_country_name   2019
# 0           Afghanistan  23.01
# 1               Albania -16.58
# 2               Algeria -23.47
# 3                Angola  19.07
# 4             Argentina  -8.77
# ..                  ...    ...
# 135             Vietnam  -7.94
# 136  West Bank and Gaza -15.59
# 137               Yemen   2.89
# 138              Zambia  27.05
# 139            Zimbabwe -23.98
#
# [140 rows x 2 columns]

# %%
merged = gdf.merge(map_dt_2019, left_on = 'country', right_on = 'base_country_name', how = 'left')

# %%
merged.tail()
# Out:
#                  country country_code  \
# 171   Republic of Serbia          SRB
# 172           Montenegro          MNE
# 173               Kosovo          KOS
# 174  Trinidad and Tobago          TTO
# 175          South Sudan          SDS
#
#                                               geometry    base_country_name  \
# 171  POLYGON ((18.82982 45.90887, 18.82984 45.90888...                  NaN
# 172  POLYGON ((20.07070 42.58863, 19.80161 42.50009...                  NaN
# 173  POLYGON ((20.59025 41.85541, 20.52295 42.21787...                  NaN
# 174  POLYGON ((-61.68000 10.76000, -61.10500 10.890...  Trinidad and Tobago
# 175  POLYGON ((30.83385 3.50917, 29.95350 4.17370, ...                  NaN
#
#       2019
# 171    NaN
# 172    NaN
# 173    NaN
# 174 -13.81
# 175    NaN

# %%
merged.fillna('No data', inplace = True)

# %%
import json
merged_json = json.loads(merged.to_json())
json_data = json.dumps(merged_json)

# %%
from bokeh.io import output_notebook, show, output_file
from bokeh.plotting import figure
from bokeh.models import GeoJSONDataSource, LinearColorMapper, ColorBar
from bokeh.palettes import brewer

# %%
geosource = GeoJSONDataSource(geojson = json_data)

# %%
palette = brewer['YlGnBu'][6]

# %%
palette = palette[::-1]

# %%
color_mapper = LinearColorMapper(palette = palette, low = -60, high = 60, nan_color = '#d9d9d9')

# %%
tick_labels = {'-60': '<-50', '-40': '-40', '-20':'-20', '0':'0', '20':'20', '40':'40', '60':'>60',
               '300':'300', '50': '>40'}

# %%
color_bar = ColorBar(color_mapper=color_mapper, label_standoff=8,width = 500, height = 20,
border_line_color=None,location = (0,0), orientation = 'horizontal', major_label_overrides = tick_labels)

# %%
p = figure(title = 'Talent Migration Rates Globally, net per 10K ,2019', plot_height = 600 , plot_width = 950,
           toolbar_location = None)
p.xgrid.grid_line_color = None
p.ygrid.grid_line_color = None

# %%
p.patches('xs','ys', source = geosource,fill_color = {'field' :'2019', 'transform' : color_mapper},
          line_color = 'black', line_width = 0.25, fill_alpha = 1)
p.add_layout(color_bar, 'below')
output_notebook()
show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1043">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="e71d878e-5f4e-4d78-9839-f2294d34258e" data-root-id="1005"></div>

# %% [markdown]
# *Missing data on the map is filled with light grey.*

# %% [markdown]
# -----

# %% [markdown]
# ## 4. Extracting Insights from Armenian Talent Migration

# %%
Armenia = data.loc[data['base_country_name'] == 'Armenia']

# %%
Armenia
# Out:
#     base_country_code base_country_name base_country_wb_income  \
# 128                am           Armenia    Upper Middle Income
# 129                am           Armenia    Upper Middle Income
# 130                am           Armenia    Upper Middle Income
# 131                am           Armenia    Upper Middle Income
# 132                am           Armenia    Upper Middle Income
# 133                am           Armenia    Upper Middle Income
# 134                am           Armenia    Upper Middle Income
#
#     base_country_wb_region target_country_code   target_country_name  \
# 128  Europe & Central Asia                  ca                Canada
# 129  Europe & Central Asia                  fr                France
# 130  Europe & Central Asia                  de               Germany
# 131  Europe & Central Asia                  ir    Iran, Islamic Rep.
# 132  Europe & Central Asia                  ae  United Arab Emirates
# 133  Europe & Central Asia                  gb        United Kingdom
# 134  Europe & Central Asia                  us         United States
#
#     target_country_wb_income    target_country_wb_region  2015  2016   2017  \
# 128              High Income               North America -2.81 -5.65  -4.06
# 129              High Income       Europe & Central Asia -1.41 -0.66  -2.14
# 130              High Income       Europe & Central Asia -6.93 -5.32  -5.42
# 131      Upper Middle Income  Middle East & North Africa -0.40  1.50   0.14
# 132              High Income  Middle East & North Africa -2.51 -1.16  -0.78
# 133              High Income       Europe & Central Asia  0.00 -0.25  -0.86
# 134              High Income               North America -3.31 -6.48 -17.82
#
#       2018   2019
# 128  -3.71  -3.14
# 129  -0.80   2.83
# 130  -3.59  -2.83
# 131   3.53   4.72
# 132   0.19  -0.52
# 133  -0.12  -0.63
# 134 -13.56 -12.89

# %%
overall_rates = dict(Armenia.sum()[8:13])

# %%
plt.figure(figsize=(10,8))
plt.plot(overall_rates.keys(), overall_rates.values(), c= 'hotpink', lw = 7)


plt.title('Emmigration Trends for Armenia, 2015-2019', fontsize=15)

plt.show()

# %%
Armenia['Average Rate'] = Armenia.loc[:,'2017':'2019'].mean(axis=1)
# Out:
# <ipython-input-73-d7805c23e57c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Armenia['Average Rate'] = Armenia.loc[:,'2017':'2019'].mean(axis=1)

# %%
sum_ = Armenia['Average Rate'].abs().sum()

# %%
percentage_ = [abs(i)/sum_*100 for i in Armenia['Average Rate']]

# %%
Armenia['Percentage'] = percentage_
# Out:
# <ipython-input-78-dccf5ab8ad51>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Armenia['Percentage'] = percentage_

# %%
list(Armenia['target_country_name'])
# Out:
# ['Canada',
#  'France',
#  'Germany',
#  'Iran, Islamic Rep.',
#  'United Arab Emirates',
#  'United Kingdom',
#  'United States']

# %%
labels = list(Armenia['target_country_name'])
rates = list(Armenia['Percentage'])
colors = ['cyan', 'silver','yellowgreen','lightpink', 'gold', 'darkslategrey','deeppink','palevioletred']
explode = (0, 0, 0, 0.2, 0, 0, 0)

plt.figure(figsize=(10,8))
patches, texts = plt.pie(rates, explode=explode, colors=colors, shadow=True, startangle=140)
plt.legend(patches, labels, loc="best")
plt.axis('equal')
plt.tight_layout()
plt.title('Migration Flows from/to Armenia, %', fontsize=15)
plt.show()

# %% [markdown]
# Exploded part represents destinations for which net migration rate is positive(flows to Armenia are greater).

# %%
import matplotlib.colors as mcolors

colors = np.where(Armenia["Average Rate"]>0,'springgreen','deeppink')
classes = 'Countries Losing to'
classes2 = 'Countries Gaining From'

plt.figure(figsize=(10,8))
plt.scatter(list(Armenia['Average Rate']), list(Armenia['target_country_name']), c = colors, s=100, label = classes)

plt.legend(fontsize=10)
plt.title('Net Country Migration for Armenia, Gaining From and Losing To', fontsize=15)
plt.show()

# %% [markdown]
# *Please note that the dataset does not include net migration rates of Russia.*

# %% [markdown]
#     Explanation: Per 10,000 citizens, about 15 more people emmigrated from Armenia to US than immigrated to Armenia during 2017-2019. For the same period, approximately 3 more people entered Armenia from Iran than left.

# %% [markdown]
# ----

# %% [markdown]
# ## 5. Exploring Flow Directions (based on income groups)

# %% [markdown]
# Usually migration flows occur from low, lower-middle, upper-middle income countries to high income ones. Let's check it out.

# %%
high_income = data.loc[data['base_country_wb_income'] == 'High Income']

# %%
income = high_income.target_country_wb_income.unique()

# %%
high_income
# Out:
#      base_country_code     base_country_name base_country_wb_income  \
# 0                   ae  United Arab Emirates            High Income
# 1                   ae  United Arab Emirates            High Income
# 2                   ae  United Arab Emirates            High Income
# 3                   ae  United Arab Emirates            High Income
# 4                   ae  United Arab Emirates            High Income
# ...                ...                   ...                    ...
# 3994                uy               Uruguay            High Income
# 3995                uy               Uruguay            High Income
# 3996                uy               Uruguay            High Income
# 3997                uy               Uruguay            High Income
# 3998                uy               Uruguay            High Income
#
#           base_country_wb_region target_country_code target_country_name  \
# 0     Middle East & North Africa                  af         Afghanistan
# 1     Middle East & North Africa                  dz             Algeria
# 2     Middle East & North Africa                  ao              Angola
# 3     Middle East & North Africa                  ar           Argentina
# 4     Middle East & North Africa                  am             Armenia
# ...                          ...                 ...                 ...
# 3994   Latin America & Caribbean                  pe                Peru
# 3995   Latin America & Caribbean                  es               Spain
# 3996   Latin America & Caribbean                  gb      United Kingdom
# 3997   Latin America & Caribbean                  us       United States
# 3998   Latin America & Caribbean                  ve       Venezuela, RB
#
#      target_country_wb_income    target_country_wb_region  2015  2016  2017  \
# 0                  Low Income                  South Asia  0.19  0.16  0.11
# 1         Upper Middle Income  Middle East & North Africa  0.19  0.25  0.57
# 2         Lower Middle Income          Sub-Saharan Africa -0.01  0.04  0.11
# 3                 High Income   Latin America & Caribbean  0.16  0.18  0.04
# 4         Upper Middle Income       Europe & Central Asia  0.10  0.05  0.03
# ...                       ...                         ...   ...   ...   ...
# 3994      Upper Middle Income   Latin America & Caribbean  0.08  0.04  0.10
# 3995              High Income       Europe & Central Asia  1.10 -1.71 -4.56
# 3996              High Income       Europe & Central Asia  0.02 -0.06 -0.79
# 3997              High Income               North America  6.73  4.16  0.97
# 3998      Upper Middle Income   Latin America & Caribbean  4.83  7.24  8.68
#
#        2018  2019
# 0     -0.05 -0.02
# 1      0.55  0.78
# 2     -0.02 -0.06
# 3      0.01  0.23
# 4     -0.01  0.02
# ...     ...   ...
# 3994  -0.01  0.29
# 3995  -6.15 -8.12
# 3996  -0.45 -0.50
# 3997   0.06 -0.49
# 3998  10.48  7.97
#
# [2415 rows x 13 columns]

# %%
# Overall flows

# %%
d = {}
for i in income:
    inc = i.split()[:-1]
    a = high_income.loc[(high_income['target_country_wb_income']==i)]
    if len(inc) == 2:
        b = str(inc[0]).lower()+'_'+str(inc[1]).lower()+'_to_high' 
    else:    
        b = str(inc[0]).lower()+'_to_high'  
    d[b] = len(a)
    a = 0
    b = 0
d
# Out:
# {'low_to_high': 104,
#  'upper_middle_to_high': 552,
#  'lower_middle_to_high': 387,
#  'high_to_high': 1372}

# %%
def in_out_flows(year):
    d_ = {}
    for i in income:
        inc = i.split()[:-1]
        a = high_income.loc[(high_income['target_country_wb_income']==i)
            & (high_income[str(year)] > 0)]
        if len(inc) == 2:
            b = str(inc[0]).lower()+'_'+str(inc[1]).lower()+'_to_high' 
        else:    
            b = str(inc[0]).lower()+'_to_high'
        prc = (len(a)/d[b])*100
        d_[b] = round(prc, 2)
        a = 0
        b = 0
    return d_

# %%
for i in range(2015, 2020):
    print(i)
    print(in_out_flows(i))
# Out:
# 2015
# {'low_to_high': 39.42, 'upper_middle_to_high': 66.67, 'lower_middle_to_high': 61.24, 'high_to_high': 48.18}
# 2016
# {'low_to_high': 45.19, 'upper_middle_to_high': 78.26, 'lower_middle_to_high': 70.8, 'high_to_high': 48.83}
# 2017
# {'low_to_high': 55.77, 'upper_middle_to_high': 83.51, 'lower_middle_to_high': 79.07, 'high_to_high': 48.25}
# 2018
# {'low_to_high': 56.73, 'upper_middle_to_high': 81.88, 'lower_middle_to_high': 78.04, 'high_to_high': 48.83}
# 2019
# {'low_to_high': 51.92, 'upper_middle_to_high': 85.14, 'lower_middle_to_high': 80.88, 'high_to_high': 47.52}

# %%
plt.bar(*zip(*in_out_flows(2019).items()), color = 'deeppink')
plt.xticks(rotation = 45)
plt.show()

# %% [markdown]
# Interestingly, according to the data, the number of inflows to low income from high income countries was even higher than the other way round in both 2015 and 2016, and then it almost equals between 2017 and 2019.
